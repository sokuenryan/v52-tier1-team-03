# %%
import pandas as pd

# %%
df = pd.read_csv("Addresses_in_the_City_of_Los_Angeles.csv")

# %%
df.head(10)
# Out:
#     HSE_ID            PIN           PIND  HSE_NBR HSE_FRAC_NBR HSE_DIR_CD  \
# 0   772643  150A187   366    150A187-366     1769          NaN          N
# 1  1044886  111B141   217    111B141-217      260          NaN          S
# 2  1042028  096B169   869    096B169-869     8802          NaN          S
# 3  1040000  147B197   608    147B197-608     4610          NaN          W
# 4  1042029  096B169   869    096B169-869     8802          1/2          S
# 5  1039775  192B101   758    192B101-758     8320          NaN          N
# 6  1045065  151-5A189 353  151-5A189-353     2031          NaN          N
# 7  1066012  129B169  1343   129B169-1343     9039          NaN          W
# 8  1040871  108B213   259    108B213-259     5500          NaN          S
# 9  1040385  174B121   796    174B121-796     5821          NaN          N
#
#       STR_NM STR_SFX_CD STR_SFX_DIR_CD UNIT_RANGE  ZIP_CD       LAT  \
# 0       IVAR        AVE            NaN        NaN   90028  34.10369
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035138 entries, 0 to 1035137
# Data columns (total 18 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   HSE_ID          1035138 non-null  int64
#  1   PIN             1035138 non-null  object
#  2   PIND            1035138 non-null  object
#  3   HSE_NBR         1035138 non-null  int64
#  4   HSE_FRAC_NBR    61350 non-null    object
#  5   HSE_DIR_CD      1034505 non-null  object
#  6   STR_NM          1035136 non-null  object
#  7   STR_SFX_CD      1016496 non-null  object
#  8   STR_SFX_DIR_CD  2226 non-null     object
#  9   UNIT_RANGE      20604 non-null    object
#  10  ZIP_CD          1035138 non-null  int64
#  11  LAT             1035138 non-null  float64
#  12  LON             1035138 non-null  float64
#  13  X_COORD_NBR     1035138 non-null  float64
#  14  Y_COORD_NBR     1035138 non-null  float64
#  15  ASGN_STTS_IND   1035138 non-null  object
# ...
